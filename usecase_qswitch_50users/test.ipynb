# %%
import numpy as np
b = np.array([ -4.9775048 ,   0.30919178,   0.89107891,   0.48538457,
       -16.41710746, -22.58071854,  -0.76891834,  -0.76816298,
        -1.22414193,  -1.09829432,  -0.87414105,  -1.91399268,
        -1.57634579,  -2.29439383,  -2.32840564,          np.nan,
                np.nan]), np.array([3.25663369, 2.82540517, 3.35321691, 3.64488211, 3.10720827,
       3.21142566, 3.02054405, 2.76157823, 2.39144293, 2.56221199,
       2.89744535, 3.16683289, 2.55956302, 2.85271744, 2.09813531,
       1.90134075, 1.66453354, 2.2394816 , 1.86640309])
for vec in b:
    print(len(vec))
