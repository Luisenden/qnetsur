# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use('seaborn-v0_8')
import numpy as np

# %% [markdown]
# ### Exploration / Exploitation

# %%
T = 1

f = lambda count, k: (1-np.log(1+count/int(T))**2)**k
x = np.linspace(0,T,100)
for k in range(0,6):
    plt.plot(x, [f(count,k) for count in x], label=f'k={k}', color=sns.color_palette()[k])
plt.legend()

# %%
from scipy.stats import truncnorm

par = (2,7)
x = 4.3
std = f(10) * (par[1] - par[0])/2
sample = truncnorm.rvs((par[0] - x) / std, (par[1] - x) / std, loc=x, scale=std, size=10000)
sample = sample.astype(int)

# %%
fig = plt.hist(sample, bins=50)
plt.xlim((0,9))
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
p = 0.5
t = np.linspace(0,1, 100)
m = 0.2
styl = [':', '--', '-']
for i, m in enumerate([0.1,0.2,0.5]):
    plt.plot(t, np.exp(p-p*t/m), label=f'upper m={m}', linestyle = styl[i])
    plt.plot(t, np.exp(-p*t/m*1/(1-p)), label=f'lower m={m}', linestyle = styl[i])
plt.ylim(0,1)
plt.ylabel(r'$P(T_{output}>t)$')
plt.xlabel(r't')
plt.legend()

# %%
t = np.linspace(1,10,100)
plt.plot(t, (1-p)**np.floor(t), label=r'$T_{gen}$')
plt.plot(t, np.exp((t-1)*np.log(1-p)), label=r'$T^{upper}_{gen}$')
plt.xlabel('t')
plt.ylabel('P(T>t)')
plt.legend()

# %%
1-np.cumsum((1-p)**(t-1)*p)/len(t)
# Out:
# array([0.99      , 0.98027617, 0.9708209 , 0.96162675, 0.95268652,
#        0.94399319, 0.93553996, 0.92732018, 0.9193274 , 0.91155537,
#        0.90399799, 0.89664931, 0.88950359, 0.88255522, 0.87579874,
#        0.86922886, 0.86284042, 0.85662841, 0.85058796, 0.84471434,
#        0.83900293, 0.83344925, 0.82804895, 0.82279779, 0.81769166,
#        0.81272655, 0.80789856, 0.8032039 , 0.7986389 , 0.79419997,
#        0.78988364, 0.78568651, 0.78160529, 0.77763679, 0.77377789,
#        0.77002556, 0.76637686, 0.76282893, 0.75937898, 0.75602431,
#        0.75276229, 0.74959035, 0.74650602, 0.74350687, 0.74059055,
#        0.73775477, 0.7349973 , 0.73231599, 0.72970873, 0.72717348,
#        0.72470824, 0.72231109, 0.71998014, 0.71771356, 0.71550959,
#        0.71336648, 0.71128255, 0.70925618, 0.70728577, 0.70536979,
#        0.70350671, 0.70169509, 0.6999335 , 0.69822056, 0.69655493,
#        0.6949353 , 0.6933604 , 0.69182899, 0.69033988, 0.68889189,
#        0.68748389, 0.68611478, 0.68478348, 0.68348894, 0.68223016,
#        0.68100614, 0.67981593, 0.67865858, 0.6775332 , 0.6764389 ,
#        0.67537482, 0.67434013, 0.67333402, 0.67235569, 0.67140438,
#        0.67047934, 0.66957985, 0.6687052 , 0.6678547 , 0.6670277 ,
#        0.66622353, 0.66544158, 0.66468122, 0.66394185, 0.66322291,
#        0.66252382, 0.66184404, 0.66118304, 0.66054029, 0.65991529])
